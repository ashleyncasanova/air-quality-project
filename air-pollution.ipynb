# %% [markdown]
# ### **[Air Pollution Level](https://www.kaggle.com/datasets/totoro29/air-pollution-level)**
#
# This dataset is about the level of Air Pollution around the globe.
#
# \
# The dataset contains 10 columns:
#
# * Country Name - It includes the names of the countries.
#
# * City - It includes the name of the town.
#
# * Year - It includes the year in which data is.
#
# * PM2.5 (μg/m3) - The Particulate Matter 2.5 pollution level in micrograms per cubic meter.
#
# * PM10 (μg/m3) - The Particulate Matter is 10 levels in microgram per cubic meter.
#
# * NO2 (μg/m3) - The Nitrogen Dioxide level in microgram p per cubic meter.
#
# * PM2.5 temporal coverage (%) - The Particulate Matter 2.5 pollution level in percentage.
#
# * PM10 temporal coverage (%) - The Particulate Matter 10 pollution level in percentage.
#
# * NO2 temporal coverage (%)- The Nitrogen Dioxide level in percentage.
#
# * Updated Year - Year in which data is updated.
#
#
# ### Additional Resources
#
# * [Technical Assistance Document for the Reporting of Daily Air Quality – the Air Quality Index (AQI)](https://www.airnow.gov/sites/default/files/2020-05/aqi-technical-assistance-document-sept2018.pdf)
#
# * [Guidelines for Developing an Air Quality (Ozone and PM2.5) Forcasting Program](https://www.airnow.gov/publications/weathercasters/guidelines-developing-air-quality-forecasting-program/)

# %%
import pandas as pd

# %%
air_pollution = pd.read_csv("air-pollution.csv")
air_pollution.head()
# Out:
#   Country Name     City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)  \
# 0  Afghanistan    Kabul  2019         119.77           NaN          NaN
# 1      Albania   Durres  2015            NaN         17.65        26.63
# 2      Albania   Durres  2016          14.32         24.56        24.78
# 3      Albania  Elbasan  2015            NaN           NaN        23.96
# 4      Albania  Elbasan  2016            NaN           NaN        26.26
#
#    PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 0                        18.0                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    NO2 temporal coverage (%)  Updated Year
# 0                        NaN          2022
# 1                  83.961187          2022
# 2                  87.932605          2022
# ...

# %%
air_pollution.tail(3)
# Out:
#       Country Name       City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)  \
# 32188     Viet Nam  Nha Trang  2015            NaN          14.0          NaN
# 32189     Viet Nam   Viet Tri  2013            NaN          27.0          NaN
# 32190     Viet Nam   Viet Tri  2014            NaN          22.0          NaN
#
#        PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 32188                         NaN                         NaN
# 32189                         NaN                         NaN
# 32190                         NaN                         NaN
#
#        NO2 temporal coverage (%)  Updated Year
# 32188                        NaN          2018
# 32189                        NaN          2018
# 32190                        NaN          2018

# %%
air_pollution["City"].head()
# Out:
# 0      Kabul
# 1     Durres
# 2     Durres
# 3    Elbasan
# 4    Elbasan
# Name: City, dtype: object

# %%
air_pollution.City.head()
# Out:
# 0      Kabul
# 1     Durres
# 2     Durres
# 3    Elbasan
# 4    Elbasan
# Name: City, dtype: object

# %%
air_pollution.loc[3] # based on index no.
# Out:
# Country Name                    Albania
# City                            Elbasan
# Year                               2015
# PM2.5 (μg/m3)                       NaN
# PM10 (μg/m3)                        NaN
# NO2 (μg/m3)                       23.96
# PM25 temporal coverage (%)          NaN
# PM10 temporal coverage (%)          NaN
# NO2 temporal coverage (%)     97.853881
# Updated Year                       2022
# Name: 3, dtype: object

# %%
air_pollution.iloc[3] # based on position
# Out:
# Country Name                    Albania
# City                            Elbasan
# Year                               2015
# PM2.5 (μg/m3)                       NaN
# PM10 (μg/m3)                        NaN
# NO2 (μg/m3)                       23.96
# PM25 temporal coverage (%)          NaN
# PM10 temporal coverage (%)          NaN
# NO2 temporal coverage (%)     97.853881
# Updated Year                       2022
# Name: 3, dtype: object

# %%
air_pollution.iloc[:3]
# Out:
#   Country Name    City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)  \
# 0  Afghanistan   Kabul  2019         119.77           NaN          NaN
# 1      Albania  Durres  2015            NaN         17.65        26.63
# 2      Albania  Durres  2016          14.32         24.56        24.78
#
#    PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 0                        18.0                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
#
#    NO2 temporal coverage (%)  Updated Year
# 0                        NaN          2022
# 1                  83.961187          2022
# 2                  87.932605          2022

# %%
len(air_pollution)
# Out:
# 32191

# %%
air_pollution.dtypes
# Out:
# Country Name                   object
# City                           object
# Year                            int64
# PM2.5 (μg/m3)                 float64
# PM10 (μg/m3)                  float64
# NO2 (μg/m3)                   float64
# PM25 temporal coverage (%)    float64
# PM10 temporal coverage (%)    float64
# NO2 temporal coverage (%)     float64
# Updated Year                    int64
# dtype: object

# %%
air_pollution.columns
# Out:
# Index(['Country Name', 'City', 'Year', 'PM2.5 (μg/m3)', 'PM10 (μg/m3)',
#        'NO2 (μg/m3)', 'PM25 temporal coverage (%)',
#        'PM10 temporal coverage (%)', 'NO2 temporal coverage (%)',
#        'Updated Year'],
#       dtype='object')

# %%
air_pollution.index
# Out:
# RangeIndex(start=0, stop=32191, step=1)

# %%
air_pollution.describe()
# Out:
#                Year  PM2.5 (μg/m3)  PM10 (μg/m3)   NO2 (μg/m3)  \
# count  32191.000000   15048.000000  21109.000000  22200.000000
# mean    2015.579354      22.920320     30.533252     20.619336
# std        2.752654      17.925906     29.312756     12.133388
# min     2000.000000       0.010000      1.040000      0.000000
# 25%     2014.000000      10.350000     16.980000     12.000000
# 50%     2016.000000      16.000000     22.000000     18.800000
# 75%     2018.000000      31.000000     31.300000     27.160000
# max     2021.000000     191.900000    540.000000    210.680000
#
#        PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# count                 7275.000000                 5381.000000
# mean                    90.794096                   90.583500
# std                     14.872681                   13.816311
# min                      0.000000                    2.568493
# 25%                     88.595890                   87.945205
# ...

# %%
air_pollution.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32191 entries, 0 to 32190
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Country Name                32191 non-null  object
#  1   City                        32191 non-null  object
#  2   Year                        32191 non-null  int64
#  3   PM2.5 (μg/m3)               15048 non-null  float64
#  4   PM10 (μg/m3)                21109 non-null  float64
#  5   NO2 (μg/m3)                 22200 non-null  float64
#  6   PM25 temporal coverage (%)  7275 non-null   float64
#  7   PM10 temporal coverage (%)  5381 non-null   float64
#  8   NO2 temporal coverage (%)   19890 non-null  float64
#  9   Updated Year                32191 non-null  int64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 2.5+ MB

# %%
air_pollution.mean()
# Out:
# /var/folders/91/blh77fzx03q_26vzlcw788pr0000gn/T/ipykernel_55015/1962595374.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   air_pollution.mean()
# Year                          2015.579354
# PM2.5 (μg/m3)                   22.920320
# PM10 (μg/m3)                    30.533252
# NO2 (μg/m3)                     20.619336
# PM25 temporal coverage (%)      90.794096
# PM10 temporal coverage (%)      90.583500
# NO2 temporal coverage (%)       93.696804
# Updated Year                  2021.744214
# dtype: float64

# %%
air_pollution["NO2 (μg/m3)"].mean()
# Out:
# 20.619336036036035

# %%
air_pollution.sum()
# Out:
# Country Name                  AfghanistanAlbaniaAlbaniaAlbaniaAlbaniaAlbania...
# City                          KabulDurresDurresElbasanElbasanElbasanKorceKor...
# Year                                                                   64883515
# PM2.5 (μg/m3)                                                         344904.97
# PM10 (μg/m3)                                                          644526.42
# NO2 (μg/m3)                                                           457749.26
# PM25 temporal coverage (%)                                        660527.048858
# PM10 temporal coverage (%)                                        487429.811646
# NO2 temporal coverage (%)                                        1863629.431234
# Updated Year                                                           65081968
# dtype: object

# %% [markdown]
# ### Filtering our DF

# %%
air_pollution.head()
# Out:
#   Country Name     City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)  \
# 0  Afghanistan    Kabul  2019         119.77           NaN          NaN
# 1      Albania   Durres  2015            NaN         17.65        26.63
# 2      Albania   Durres  2016          14.32         24.56        24.78
# 3      Albania  Elbasan  2015            NaN           NaN        23.96
# 4      Albania  Elbasan  2016            NaN           NaN        26.26
#
#    PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 0                        18.0                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    NO2 temporal coverage (%)  Updated Year
# 0                        NaN          2022
# 1                  83.961187          2022
# 2                  87.932605          2022
# ...

# %%
# If we only want to view countries whith a value of PM2.5 (μg/m3) > 35

air_pollution[air_pollution["PM2.5 (μg/m3)"] > 35].head()
# Out:
#      Country Name        City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)  \
# 0     Afghanistan       Kabul  2019         119.77           NaN          NaN
# 129     Australia      Hobart  2010          35.60           NaN          NaN
# 131     Australia      Hobart  2012          37.50           NaN          NaN
# 133     Australia      Hobart  2013          48.70           NaN          NaN
# 1205      Bahrain  Hamad Town  2012          65.52        317.88          NaN
#
#       PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 0                          18.00                         NaN
# 129                          NaN                         NaN
# 131                        97.48                   96.928572
# 133                        93.05                   93.328571
# 1205                       86.00                         NaN
#
#       NO2 temporal coverage (%)  Updated Year
# 0                           NaN          2022
# ...

# %%
# If we only want to view data in Hobart
air_pollution[air_pollution["City"] == "Hobart"].head()
# Out:
#     Country Name    City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)  \
# 129    Australia  Hobart  2010           35.6           NaN          NaN
# 130    Australia  Hobart  2011           24.9           NaN          NaN
# 131    Australia  Hobart  2012           37.5           NaN          NaN
# 132    Australia  Hobart  2013            6.1           NaN          NaN
# 133    Australia  Hobart  2013           48.7           NaN          NaN
#
#      PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 129                         NaN                         NaN
# 130                       96.99                   98.171429
# 131                       97.48                   96.928572
# 132                       97.49                   96.928572
# 133                       93.05                   93.328571
#
#      NO2 temporal coverage (%)  Updated Year
# 129                        NaN          2018
# 130                     89.714          2018
# ...

# %%
pd.crosstab(air_pollution["Country Name"], air_pollution["Year"])
# Out:
# Year                                2000  2001  2002  2003  2004  2006  2007  \
# Country Name
# Afghanistan                            0     0     0     0     0     0     0
# Albania                                0     0     0     0     0     0     0
# Algeria                                0     0     0     0     0     0     0
# Andorra                                0     0     0     0     0     0     0
# Argentina                              0     0     0     0     0     0     0
# ...                                  ...   ...   ...   ...   ...   ...   ...
# United States of America               0     0     0     0     0     0     0
# Uruguay                                0     0     0     0     0     0     0
# Uzbekistan                             0     0     0     0     0     0     0
# Venezuela (Bolivarian Republic of)     0     0     0     0     0     0     0
# Viet Nam                               0     0     0     0     0     0     0
#
# ...

# %%
air_pollution.groupby(["Country Name"]).mean()
# Out:
# /var/folders/91/blh77fzx03q_26vzlcw788pr0000gn/T/ipykernel_55015/674105831.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   air_pollution.groupby(["Country Name"]).mean()
#                                            Year  PM2.5 (μg/m3)  PM10 (μg/m3)  \
# Country Name
# Afghanistan                         2019.000000     119.770000           NaN
# Albania                             2015.750000      19.372000     25.575000
# Algeria                             2019.000000      21.530000           NaN
# Andorra                             2015.857143            NaN     25.701429
# Argentina                           2016.500000      10.185000     26.010000
# ...                                         ...            ...           ...
# ...

# %% [markdown]
# ### Visualizations

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
air_pollution["PM2.5 (μg/m3)"].plot()
# Out:
# <AxesSubplot: >

# %%
air_pollution["PM2.5 (μg/m3)"].hist()
air_pollution["PM2.5 (μg/m3)"].max()
# Out:
# 191.9

# %%
air_pollution["PM10 (μg/m3)"].hist()
air_pollution["PM10 (μg/m3)"].max()
# Out:
# 540.0

# %% [markdown]
# ### Manipulating Data

# %%
# Let's create a new data frame that excludes data points with missing values...

# Recall our original data frame
air_pollution.head()
# Out:
#   Country Name     City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)  \
# 0  Afghanistan    Kabul  2019         119.77           NaN          NaN
# 1      Albania   Durres  2015            NaN         17.65        26.63
# 2      Albania   Durres  2016          14.32         24.56        24.78
# 3      Albania  Elbasan  2015            NaN           NaN        23.96
# 4      Albania  Elbasan  2016            NaN           NaN        26.26
#
#    PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 0                        18.0                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    NO2 temporal coverage (%)  Updated Year
# 0                        NaN          2022
# 1                  83.961187          2022
# 2                  87.932605          2022
# ...

# %%
print(f'The air_pollution dataframe has {len(air_pollution)} data points.')
# Out:
# The air_pollution dataframe has 32191 data points.

# %%
air_pollution_dropped = air_pollution.dropna()
air_pollution_dropped.head()
# Out:
#    Country Name      City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)  \
# 28    Australia  Adelaide  2013           7.25         16.87         8.65
# 29    Australia  Adelaide  2014           7.10         16.66         9.40
# 30    Australia  Adelaide  2015           7.45         16.06         9.78
# 31    Australia  Adelaide  2016           6.88         16.19         8.27
# 32    Australia  Adelaide  2017           7.54         16.47        13.45
#
#     PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 28                       97.50                   96.928571
# 29                       96.55                   98.171429
# 30                       97.40                   96.928571
# 31                       93.05                   93.328571
# 32                       95.20                   95.428571
#
#     NO2 temporal coverage (%)  Updated Year
# 28                      94.47          2018
# 29                      96.34          2018
# ...

# %%
print(f'The air_pollution_dropped dataframe has {len(air_pollution_dropped)} data points... {len(air_pollution)-len(air_pollution_dropped)} data points were removed from original dataframe.')
# Out:
# The air_pollution_dropped dataframe has 1658 data points... 30533 data points were removed from original dataframe.

# %%
# Now, let's export our new dataframe...
air_pollution_dropped.to_csv('air-pollution-dropped.csv')

# %% [markdown]
# ### Creating data from existing data

# %%
air_pollution.dtypes
# Out:
# Country Name                   object
# City                           object
# Year                            int64
# PM2.5 (μg/m3)                 float64
# PM10 (μg/m3)                  float64
# NO2 (μg/m3)                   float64
# PM25 temporal coverage (%)    float64
# PM10 temporal coverage (%)    float64
# NO2 temporal coverage (%)     float64
# Updated Year                    int64
# dtype: object

# %%
air_pollution.head()
# Out:
#   Country Name     City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  NO2 (μg/m3)  \
# 0  Afghanistan    Kabul  2019         119.77           NaN          NaN
# 1      Albania   Durres  2015            NaN         17.65        26.63
# 2      Albania   Durres  2016          14.32         24.56        24.78
# 3      Albania  Elbasan  2015            NaN           NaN        23.96
# 4      Albania  Elbasan  2016            NaN           NaN        26.26
#
#    PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 0                        18.0                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    NO2 temporal coverage (%)  Updated Year
# 0                        NaN          2022
# 1                  83.961187          2022
# 2                  87.932605          2022
# ...

# %% [markdown]
# ### Shuffle Data

# %%
air_pollution_shuffled = air_pollution.sample(frac=1)
len(air_pollution_shuffled)
# Out:
# 32191

# %%
air_pollution_shuffled.head(3)
# Out:
#       Country Name                     City  Year  PM2.5 (μg/m3)  \
# 26957        Spain  Sant Antoni De Portmany  2010            NaN
# 19560        Italy                    Schio  2014            NaN
# 21439  New Zealand         Waitomo District  2014            NaN
#
#        PM10 (μg/m3)  NO2 (μg/m3)  PM25 temporal coverage (%)  \
# 26957         20.64          NaN                         NaN
# 19560         22.64        19.49                         NaN
# 21439         15.89          NaN                         NaN
#
#        PM10 temporal coverage (%)  NO2 temporal coverage (%)  Updated Year
# 26957                      86.518                        NaN          2022
# 19560                         NaN                  97.420091          2022
# 21439                     100.000                        NaN          2022

# %%
# Only select 10% of data
air_pollution_shuffled = air_pollution.sample(frac=0.1)
len(air_pollution_shuffled)
# Out:
# 3219

# %%
air_pollution_shuffled.head(3)
# Out:
#       Country Name             City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  \
# 25143        Spain  Arganda Del Rey  2015            NaN         22.37
# 6696         China     Tongren Xian  2015          52.27           NaN
# 10232       France         Lucciana  2015            NaN         18.02
#
#        NO2 (μg/m3)  PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 25143        23.35                         NaN                         NaN
# 6696           NaN                       100.0                         NaN
# 10232         6.80                         NaN                         NaN
#
#        NO2 temporal coverage (%)  Updated Year
# 25143                  97.705479          2022
# 6696                         NaN          2022
# 10232                  99.474886          2022

# %% [markdown]
# ### Unshuffle Data

# %%
air_pollution_shuffled.reset_index(drop=True,inplace=True)
# drop=True removes shuffled index column

# %%
air_pollution_shuffled.head(3)
# Out:
#   Country Name             City  Year  PM2.5 (μg/m3)  PM10 (μg/m3)  \
# 0        Spain  Arganda Del Rey  2015            NaN         22.37
# 1        China     Tongren Xian  2015          52.27           NaN
# 2       France         Lucciana  2015            NaN         18.02
#
#    NO2 (μg/m3)  PM25 temporal coverage (%)  PM10 temporal coverage (%)  \
# 0        23.35                         NaN                         NaN
# 1          NaN                       100.0                         NaN
# 2         6.80                         NaN                         NaN
#
#    NO2 temporal coverage (%)  Updated Year
# 0                  97.705479          2022
# 1                        NaN          2022
# 2                  99.474886          2022
